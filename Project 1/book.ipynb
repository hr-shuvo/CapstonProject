# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

data.head()
# Out:
#    Rank                                              Title  \
# 0     1            The Hunger Games (The Hunger Games, #1)
# 1     2  Harry Potter and the Order of the Phoenix (Har...
# 2     3                                Pride and Prejudice
# 3     4                              To Kill a Mockingbird
# 4     5                                     The Book Thief
#
#                             Author  Rating  Rating Count    Score  \
# 0                  Suzanne Collins    4.34       9228216  4022255
# 1                     J.K. Rowling    4.50       3584219  3196853
# 2                      Jane Austen    4.29       4479689  2834565
# 3                       Harper Lee    4.26       6507363  2503818
# 4  Markus Zusak (Goodreads Author)    4.39       2722178  1885264
#
#    People Voted                                              Image
# 0         40910  https://i.gr-assets.com/images/S/compressed.ph...
# 1         32657  https://i.gr-assets.com/images/S/compressed.ph...
# ...

# %%
df = data.copy()

df.shape
# Out:
# (1000, 8)

# %%
max(df['Rating'])
# Out:
# 4.81

# %%
duplicates = df[df['Title'].duplicated(keep=False)]
duplicates
# Out:
#      Rank                                              Title  \
# 3       4                              To Kill a Mockingbird
# 36     37                                     Fahrenheit 451
# 41     42                                               1984
# 82     83  The Fellowship of the Ring (The Lord of the Ri...
# 88     89                              To Kill a Mockingbird
# 104   105                                     Fahrenheit 451
# 179   180  A Court of Mist and Fury (A Court of Thorns an...
# 266   267  The Fellowship of the Ring (The Lord of the Ri...
# 304   305                                               1984
# 328   329  A Court of Thorns and Roses (A Court of Thorns...
# 484   485  A Court of Mist and Fury (A Court of Thorns an...
# 533   534  A Court of Wings and Ruin (A Court of Thorns a...
# 845   846  A Court of Thorns and Roses (A Court of Thorns...
# 960   961  A Court of Wings and Ruin (A Court of Thorns a...
#
# ...
