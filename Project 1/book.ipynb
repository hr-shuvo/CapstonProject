# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

data.head()
# Out:
#    Rank                                              Title  \
# 0     1            The Hunger Games (The Hunger Games, #1)
# 1     2  Harry Potter and the Order of the Phoenix (Har...
# 2     3                                Pride and Prejudice
# 3     4                              To Kill a Mockingbird
# 4     5                                     The Book Thief
#
#                                Author                               Rating
# 0                  by Suzanne Collins  4.34 avg rating — 9,228,147 ratings
# 1                     by J.K. Rowling  4.50 avg rating — 3,584,208 ratings
# 2                      by Jane Austen  4.29 avg rating — 4,479,650 ratings
# 3                       by Harper Lee  4.26 avg rating — 6,507,320 ratings
# 4  by Markus Zusak (Goodreads Author)  4.39 avg rating — 2,722,160 ratings

# %%
data.shape
# Out:
# (200, 4)
